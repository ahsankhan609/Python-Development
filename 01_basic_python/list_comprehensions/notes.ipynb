# %% [markdown]
# # Python List Comprehension

# %% [markdown]
# - List comprehensions in Python provide a concise way to create lists by embedding a loop and optional conditional logic in a single line.
# - You use a list comprehension to transform and filter elements from an iterable efficiently.
# - It allows you to replace complex loops and `map()` functions with more readable and often faster expressions.
# - you can optimize your code for better performance and clarity.

# %% [markdown]
# ### Transforming Lists in Python

# %% [markdown]
# - There are a few different ways to create and add items to a lists in Python.
# - In this section, you’ll explore for loops and the `map()` function to perform these tasks.
# - Then, you’ll move on to learn about how to use list comprehensions and when list comprehensions can benefit your Python program.

# %% [markdown]
# #### Use for Loops to create lists

# %% [markdown]
# - Here, you instantiate an empty list named **squares**.
# - Then, you use a for loop to iterate over range(10).
# - Finally, you multiply each number by itself and append the result to the end of the list.

# %%
squares: list[int] = []

for number in range(10):
    squares.append(number * number)

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #### Work With `map()` Objects to create list

# %%
prices_of_items: list[float] = [1.09, 23.56, 57.84, 4.56, 6.78]

TAX_RATE: float = 0.08


def get_price_with_tax(price):
    return price * (1 + TAX_RATE)


final_price_of_cart_with_tax_inclusive = map(
    get_price_with_tax, prices_of_items)
print(final_price_of_cart_with_tax_inclusive)  # print the object


print(list(final_price_of_cart_with_tax_inclusive))  # print final list
# Out:
# ...
# [1.1772000000000002, 25.4448, 62.467200000000005, 4.9248, 7.322400000000001]

# %% [markdown]
# #### Leverage List Comprehensions to generate list

# %% [markdown]
# Rather than creating an empty list and adding each element to the end, you simply define the list and its contents at the same time by following this format:

# %% [markdown]
# ```python
# new_list = [expression for member in iterable]
# ```

# %% [markdown]
# **Every list comprehension in Python includes three elements:**
#
# 1. **expression** is the member itself, a call to a method, or any other valid expression that returns a value. In the example below, the expression `number * number` is the square of the `member value`.
# 2. **member** is the object or value in the list or iterable. In the example below, the member value is `number from range(10)`.
# 3.**iterable** is a list, set, sequence, generator, or any other object that can return its elements one at a time. In the example below, the iterable is `range(10)`.

# %% [markdown]
# List comprehensions are a third way of making or transforming lists. With this elegant approach, you could rewrite the for loop from the first example in just a single line of code:

# %%
squares = [number * number for number in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
prices_of_items: list[float] = [1.09, 23.56, 57.84, 4.56, 6.78]

TAX_RATE: float = 0.08


def get_price_with_tax(price):
    return price * (1 + TAX_RATE)


final_price_of_cart_with_tax_inclusive = [
    get_price_with_tax(price) for price in prices_of_items]
print(final_price_of_cart_with_tax_inclusive)
# Out:
# [1.1772000000000002, 25.4448, 62.467200000000005, 4.9248, 7.322400000000001]
